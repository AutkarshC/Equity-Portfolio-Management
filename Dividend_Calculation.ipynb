# %%
head(ibm)
div_df_ibm = ibm %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_ibm)

head(aapl)
div_df_aapl = aapl %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_aapl)

head(amzn)
div_df_amzn = amzn %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_amzn)

head(fb)
div_df_fb= fb %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_fb)

head(goog)
div_df_goog= goog %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_goog)

head(msft)
div_df_msft= msft %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_msft)

head(orcl)
div_df_orcl = orcl %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_orcl)

head(sap)
div_df_sap = sap %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_sap)

head(tsla)
div_df_tsla = tsla %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_tsla)

head(nflx)
div_df_nflx = nflx %>%
mutate(ratio_Close = lag(Close)/Close, ratio_Adj.Close = lag(Adj.Close)/Adj.Close) %>%
mutate(difference = ratio_Close - ratio_Adj.Close) %>%
mutate(dividend = difference * Close) %>%
select(Date, dividend) %>%
filter(dividend > 0.01)
head(div_df_nflx)
